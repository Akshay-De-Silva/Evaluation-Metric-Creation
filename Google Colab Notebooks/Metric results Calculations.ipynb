# %%
#all data used is from the other files where the values were calulated
#equations will be using the neaural network values as currently being calculated
weightF1 = 0.5
weightRS = 0.5

weightGPU = 0.5
weightCPU = 0.5
weightRAM = 0.5

# %%
#RAF1 (GPU)
normalizedF1Score = (0.97-0.96)/(0.98-0.96)
RAF1_GPU = (weightF1*normalizedF1Score) + (weightGPU*(1-(1253.4-1048.6)/(1470.2-1048.6)))
print(f"Neural Network RAF1 (GPU) {round(RAF1_GPU,4)}")

normalizedF1Score = (0.98-0.96)/(0.98-0.96)
RAF1_GPU = (weightF1*normalizedF1Score) + (weightGPU*(1-(1470.2-1048.6)/(1470.2-1048.6)))
print(f"Convolutional Neural Network RAF1 (GPU) {round(RAF1_GPU,4)}")

normalizedF1Score = (0.96-0.96)/(0.98-0.96)
RAF1_GPU = (weightF1*normalizedF1Score) + (weightGPU*(1-(1048.6-1048.6)/(1470.2-1048.6)))
print(f"Recurrent Neural Network RAF1 (GPU) {round(RAF1_GPU,4)}")
# Out:
# Neural Network RAF1 (GPU) 0.5071
# Convolutional Neural Network RAF1 (GPU) 0.5
# Recurrent Neural Network RAF1 (GPU) 0.5

# %%
#RARS (GPU)
normalizedRSScore = (0.8923-0.8896)/(0.9248-0.8896)
RARS_GPU = (weightRS*normalizedRSScore) + (weightGPU*(1-(2175.0-2175.0)/(2187.0-2175.0)))
print(f"Neural Network RARS (GPU) {round(RARS_GPU,4)}")

normalizedRSScore = (0.9248-0.8896)/(0.9248-0.8896)
RARS_GPU = (weightRS*normalizedRSScore) + (weightGPU*(1-(2187.0-2175.0)/(2187.0-2175.0)))
print(f"Convolutional Neural Network RARS (GPU) {round(RARS_GPU,4)}")

normalizedRSScore = (0.8896-0.8896)/(0.9248-0.8896)
RARS_GPU = (weightRS*normalizedRSScore) + (weightGPU*(1-(2175.0-2175.0)/(2187.0-2175.0)))
print(f"Recurrent Neural Network RARS (GPU) {round(RARS_GPU,4)}")
# Out:
# Neural Network RARS (GPU) 0.5384
# Convolutional Neural Network RARS (GPU) 0.5
# Recurrent Neural Network RARS (GPU) 0.5

# %%
#RAF1 (CPU)
normalizedF1Score = (0.9724-0.9574)/(0.9832-0.9574)
RAF1_CPU = (weightF1*normalizedF1Score) + (weightCPU*(1-(27.9-18.6)/(42.4-18.6)))
print(f"Neural Network RARS (CPU) {round(RAF1_CPU,4)}")

normalizedF1Score = (0.9832-0.9574)/(0.9832-0.9574)
RAF1_CPU = (weightF1*normalizedF1Score) + (weightCPU*(1-(18.6-18.6)/(42.4-18.6)))
print(f"Convolutional Neural Network RARS (CPU) {round(RAF1_CPU,4)}")

normalizedF1Score = (0.9574-0.9574)/(0.9832-0.9574)
RAF1_CPU = (weightF1*normalizedF1Score) + (weightCPU*(1-(42.4-18.6)/(42.4-18.6)))
print(f"Recurrent Neural Network RARS (CPU) {round(RAF1_CPU,4)}")
# Out:
# Neural Network RARS (CPU) 0.5953
# Convolutional Neural Network RARS (CPU) 1.0
# Recurrent Neural Network RARS (CPU) 0.0

# %%
#RARS (CPU)
normalizedRSScore = (0.8922-0.881)/(0.8922-0.881)
RARS_CPU = (weightRS*normalizedRSScore) + (weightCPU*(1-(20.3-2.82)/(20.9-2.82)))
print(f"Neural Network RARS (CPU) {round(RARS_CPU,4)}")

normalizedRSScore = (0.8884-0.881)/(0.8922-0.881)
RARS_CPU = (weightRS*normalizedRSScore) + (weightCPU*(1-(2.82-2.82)/(20.9-2.82)))
print(f"Convolutional Neural Network RARS (CPU) {round(RARS_CPU,4)}")

normalizedRSScore = (0.881-0.881)/(0.8922-0.881)
RARS_CPU = (weightRS*normalizedRSScore) + (weightCPU*(1-(20.9-2.82)/(20.9-2.82)))
print(f"Recurrent Neural Network RARS (CPU) {round(RARS_CPU,4)}")
# Out:
# Neural Network RARS (CPU) 0.5166
# Convolutional Neural Network RARS (CPU) 0.8304
# Recurrent Neural Network RARS (CPU) 0.0

# %%
#RAF1 (RAM)
normalizedF1Score = (0.97-0.96)/(0.98-0.96)
RAF1_RAM = (weightF1*normalizedF1Score) + (weightRAM*(1-(1996.9515625-1871.6546875)/(1996.9515625-1871.6546875)))
print(f"Neural Network RARS (RAM) {round(RAF1_RAM,4)}")

normalizedF1Score = (0.98-0.96)/(0.98-0.96)
RAF1_RAM = (weightF1*normalizedF1Score) + (weightRAM*(1-(1967.075-1871.6546875)/(1996.9515625-1871.6546875)))
print(f"Convolutional Neural Network RARS (RAM) {round(RAF1_RAM,4)}")

normalizedF1Score = (0.96-0.96)/(0.98-0.96)
RAF1_RAM = (weightF1*normalizedF1Score) + (weightRAM*(1-(1871.6546875-1871.6546875)/(1996.9515625-1871.6546875)))
print(f"Recurrent Neural Network RARS (RAM) {round(RAF1_RAM,4)}")
# Out:
# Neural Network RARS (RAM) 0.25
# Convolutional Neural Network RARS (RAM) 0.6192
# Recurrent Neural Network RARS (RAM) 0.5

# %%
#RARS (RAM)
normalizedRSScore = (0.97-0.96)/(0.98-0.96)
RARS_RAM = (weightRS*normalizedRSScore) + (weightRAM*(1-(1996.9515625-1871.6546875)/(1996.9515625-1871.6546875)))
print(f"Neural Network RARS (RAM) {round(RARS_RAM,4)}")

normalizedRSScore = (0.98-0.96)/(0.98-0.96)
RARS_RAM = (weightRS*normalizedRSScore) + (weightRAM*(1-(1967.075-1871.6546875)/(1996.9515625-1871.6546875)))
print(f"Convolutional Neural Network RARS (RAM) {round(RARS_RAM,4)}")

normalizedRSScore = (0.96-0.96)/(0.98-0.96)
RARS_RAM = (weightRS*normalizedRSScore) + (weightRAM*(1-(1871.6546875-1871.6546875)/(1996.9515625-1871.6546875)))
print(f"Recurrent Neural Network RARS (RAM) {round(RARS_RAM,4)}")
# Out:
# Neural Network RARS (RAM) 0.25
# Convolutional Neural Network RARS (RAM) 0.6192
# Recurrent Neural Network RARS (RAM) 0.5
